# %%
import os
result=[]
def search(dirname):
    try:
        filenames = os.listdir(dirname)
        for filename in filenames:
            full_filename = os.path.join(dirname, filename)
            if os.path.isdir(full_filename):
                search(full_filename)
            else:
                ext = os.path.splitext(full_filename)[-1]
                if ext == '.jpg': 
                    #print(full_filename)
                    result.append(full_filename)
    except PermissionError:
        pass

search("/home/lab/다운로드/dogs_and_cats/dogs")

# %%
import os
result1=[]
def search(dirname):
    try:
        filenames = os.listdir(dirname)
        for filename in filenames:
            full_filename = os.path.join(dirname, filename)
            if os.path.isdir(full_filename):
                search(full_filename)
            else:
                ext = os.path.splitext(full_filename)[-1]
                if ext == '.jpg': 
                    #print(full_filename)
                    result1.append(full_filename)
    except PermissionError:
        pass

search("/home/lab/다운로드/dogs_and_cats/cats")

# %%
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm, tqdm_notebook
from tqdm import trange
import time
import numpy as np

# %%
img_exp=cv2.imread(result[0])
img_exp=cv2.resize(img_exp,dsize=(150,150))
plt.imshow(img_exp)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img_exp.shape
# Out:
# (150, 150, 3)

# %%
result[0]
# Out:
# '/home/lab/다운로드/dogs_and_cats/dogs/dog.428.jpg'

# %%
data_height=50
data_width=50
channel_n=3

dogs_images = np.zeros((len(result[:1000]), data_height, data_width, channel_n)) 
for n, path in tqdm(enumerate(result[:1000])):
    time.sleep(0.0000000001)
    image = cv2.imread(result[n])/255
    image = cv2.resize(image, (data_height, data_width))
    dogs_images[n, :, :, :] = image
# Out:
# 1000it [00:01, 667.32it/s]

# %%
dogs_images.shape
# Out:
# (1000, 50, 50, 3)

# %%
dogs_images[0]
# Out:
# array([[[0.45401961, 0.61480392, 0.7677451 ],
#         [0.45394118, 0.61472549, 0.76766667],
#         [0.59466667, 0.70535294, 0.87694118],
#         ...,
#         [0.14017647, 0.1402549 , 0.72160784],
#         [0.10384314, 0.10592157, 0.61368627],
#         [0.15958824, 0.09768627, 0.47370588]],
#
#        [[0.44337255, 0.60415686, 0.75709804],
#         [0.54890196, 0.70968628, 0.86262745],
#         [0.38396079, 0.56988236, 0.72882353],
#         ...,
#         [0.13333333, 0.10807843, 0.64429412],
#         [0.14498039, 0.1164902 , 0.59331372],
#         [0.23631373, 0.2237451 , 0.33158824]],
#
#        [[0.48637253, 0.6530392 , 0.80205881],
#         [0.48490189, 0.63225484, 0.76470582],
#         [0.5162745 , 0.68509803, 0.83411764],
#         ...,
#         [0.13745098, 0.09411765, 0.59715686],
#         [0.18235294, 0.19323529, 0.38450977],
#         [0.33392159, 0.28098041, 0.39225492]],
#
#        ...,
#
#        [[0.57911724, 0.75882305, 0.88039168],
# ...

# %%
data_height=50
data_width=50
channel_n=3

cats_images = np.zeros((len(result1[:1000]), data_height, data_width, channel_n)) 
for n, path in tqdm(enumerate(result1[:1000])):
    time.sleep(0.00000000001)
    image = cv2.imread(result1[n])/255
    image = cv2.resize(image, (data_height, data_width))
    cats_images[n, :, :, :] = image
# Out:
# 1000it [00:01, 710.75it/s]

# %%
cats_images.shape
# Out:
# (1000, 50, 50, 3)

# %%
cats_images[0]
# Out:
# array([[[0.28015373, 0.32229333, 0.39888   ],
#         [0.38067137, 0.36382118, 0.43317647],
#         [0.30259607, 0.32108235, 0.41912156],
#         ...,
#         [0.5068863 , 0.47551375, 0.47943532],
#         [0.50091921, 0.46954666, 0.47346823],
#         [0.52425398, 0.49288143, 0.496803  ]],
#
#        [[0.3369851 , 0.34805647, 0.38792157],
#         [0.3075153 , 0.30831373, 0.38593412],
#         [0.2527451 , 0.29980392, 0.39392157],
#         ...,
#         [0.49933338, 0.46796083, 0.4718824 ],
#         [0.53620861, 0.50483606, 0.50875763],
#         [0.51345094, 0.48207839, 0.48599996]],
#
#        [[0.33803922, 0.35372549, 0.42431373],
#         [0.31231372, 0.32752941, 0.39996078],
#         [0.22784313, 0.28274509, 0.37294117],
#         ...,
#         [0.50031374, 0.46501962, 0.47678433],
#         [0.52474511, 0.49337256, 0.49729413],
#         [0.52284716, 0.49147461, 0.49539618]],
#
#        ...,
#
#        [[0.45211772, 0.44035301, 0.47564713],
# ...

# %%
import numpy as np
dogs_images=np.array(dogs_images)
cats_images=np.array(cats_images)

# %%
np.save("dogs.npy",dogs_images)
np.save("cats.npy",cats_images)
